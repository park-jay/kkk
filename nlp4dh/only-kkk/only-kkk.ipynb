# %%
import pandas as pd

# %%
data=pd.read_feather('/Volumes/T7/chroniclingamerica/american-stories/kkk-revival-stanza-lynch.feather')

# %%
data[data['article'].str.contains('klan|klux|ku')].reset_index(drop=True).to_feather('/Volumes/T7/chroniclingamerica/american-stories/only-kkk-revival.feather')
